# %% [markdown]
# # 1、什么是神经网络？
# > 人工神经网络( Artificial Neural Network， 简写为ANN)也简称为神经网络(NN)，是一种模仿生物神经网络结 构和功能的计算模型。人脑可以看做是一个生物神经网络，由众多的神经元连接而成。
#
#
# # 2、人工神经元的基本结构是什么？
#
# ![人工神经元](./img/人工神经元.png)
#
# - 输入层: 输入部分x
# - 隐藏层：权重部分、加权求和、激活函数三部分
# - 输出层：f(x)
#
#
# # 3、什么是神经网络的内部状态和激活值？
# - 内部状态：神经网络接收到输入、历史信息以及网格内部的权重计算后结果
# - 激活值：激活函数对内部状态进行非线性变换后得到的结果
#
#
# # 4、什么是激活函数？
#
#
# # 5、常见的激活函数有哪些？

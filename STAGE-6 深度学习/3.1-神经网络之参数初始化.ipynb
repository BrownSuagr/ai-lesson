# %% [markdown]
# # 参数初始化定义
# - 在构建网络
#
# # 参数初始化作用
# - 防止梯度消失或梯度爆炸：初始权重值过大或过小导致梯度在传播过程中指数级增大或缩小
# - 提高收敛速度：合理的初始化导致网络中激活值分布适中，有助于梯度高效更新
# - 保持对称性破除：权重初始化需要打破对称性，否则对网络的学习能力有限制
#
# # 常见参数初始化方法
#
# ## 随机初始化
# - 均匀分布初始化：
# - 正态分布初始化：
#
# 优点：
# 缺点：
#
#
# ## 全零初始化
# ## 全一初始化
# ## 固定值初始化
# ## KaiMing初始化
# ## Xavier初始化
#
#
# # 如何选择初始化方法
#
#
# #

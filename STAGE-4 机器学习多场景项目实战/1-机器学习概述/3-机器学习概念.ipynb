# %%
# 机器学习的学习目标
# 1、掌握基于规则学习和基于模型学习的区别
# 2、掌握数据集相关概念

# %%
# 机器学习的基本概念：机器学习专门研究计算机怎样模拟或实现人类的学习行为，使之不断改善自身性能。是一门能够发掘数据价值的算法和应用，我们生活在一个数据资源非常丰富的年代，通过机器学习中的自学习算法，可以将这些数据转换为知识。
# 基于模型学习：基于模型的学习就是通过编写机器学习程序，让机器自己学习从历史数据中获得经验、训练模型：

# %%
# 小结
# 1、基于规则的分类器是使用一组 "if…else…" 规则来对样本进行分类的技术
# 2、基于模型的学习是从数据集中学习知识来获取模型，通过模型来对样本进行分类的技术
# 3、机器学习的数据集：样本，特征，目标，训练集，测试集

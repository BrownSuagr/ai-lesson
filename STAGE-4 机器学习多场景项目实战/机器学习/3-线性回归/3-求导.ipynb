# %% [markdown]
# # 求导学习目标
# - 了解常见的求导方法
# - 了解求导的四则运算
#
# ---
#
# # 1、倒数定义？
# > 导数（Derivative），也叫导函数值。又名微商，是微积分中的重要基础概念
#
# # 2、常见函数的倒数
# ![常见函数导数](../img/常见函数导数.png)
#
# # 3、倒数的四则运算
# ![求导四则运算](../img/求导四则运算.png)
#
# # 4、小结
# > 常见函数的求导方式和导数的四则运算

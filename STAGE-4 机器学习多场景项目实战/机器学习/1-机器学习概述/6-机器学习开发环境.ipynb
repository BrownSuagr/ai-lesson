# %% [markdown]
# # 机器学习开发框架
# 基于Python的 scikit-learn 库：
# - 简单高效的数据挖掘和数据分析工具
# - 可供大家使用，可在各种环境中重复使用
# - 建立在NumPy，SciPy和matplotlib上
# - 开源，可商业使用-获取BSD许可证

# %% [markdown]
# # 总结
# > 机器学习最常使用的 scikit-learn 库来解决问题，scikit-learn 封装了很多常用的机器学习算法

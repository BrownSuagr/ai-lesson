# %% [markdown]
# # 金融分控特征工程之特征评估与筛选学习目标
# - 掌握单特征分析的衡量指标
# - 知道IV、PSI等指标含义
# - 知道多特征筛选的常用方法
# - 掌握Boruta、VIF、RFE、L1等特征筛选的使用方法
#
#
# # 1、什么是单特征？
#
# # 2、特征分析一般从哪些角度入手？
# 一般从这四个角度分析覆盖度、区分度、相关性、稳定性，具体如下
# - 覆盖度：采集lei a
# - 区分度：
# - 相关性：
# - 稳定性：
#
# # 3、
